# %%
import pandas as pd
import sys 
import numpy as np
import random
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
parser = English()
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
from nltk.corpus import wordnet as wn
from gensim import corpora
import pickle
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
import time

file_ = '/home/social-sim/Documents/SocialSimCodeTesting/GCN/sgc/preprocess_DARPA_data/raw_data/twitter_cve/attr_74074.csv'
user_attr = pd.read_csv(file_)#,nrows=1000)
user_attr = user_attr.dropna()
print(user_attr.columns)
cols = ['id_h']
s= user_attr.groupby('id_h')["hashtags.keyword: Descending"].apply(lambda x: "{%s}" % ', '.join(x))
#texts = user_attr["user.description_m.keyword: Descending"]
texts = s#user_attr["hashtags.keyword: Descending"]
print(texts.head())

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def prepare_text_for_lda(text):
	try:
		tokens = tokenize(text)
		tokens = [token for token in tokens if len(token) > 4]
		tokens = [token for token in tokens if token not in en_stop]
		tokens = [get_lemma(token) for token in tokens]
		return tokens
	except:
		print(pd.isnull(text))
		sys.exit()


text_data = []
for line in texts.values.tolist():
	if not pd.isnull(line):
		tokens = prepare_text_for_lda(line)
		if random.random() > .99:
			print(tokens)
			text_data.append(tokens)
	else:
		continue


dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

import gensim
#NUM_TOPICS = 15
start, limit, step = 2, 40, 3
multi_coherence_values=[]
for n in range(10):
    coherence_values = []
    for NUM_TOPICS in range(start, limit, step):
        ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=20)
        ldamodel.save('model5.gensim')
        topics = ldamodel.print_topics(num_words=4)
        for topic in topics:
            print(topic)

        dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
        corpus = pickle.load(open('corpus.pkl', 'rb'))
        lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
        coherence_model_lda = CoherenceModel(model=lda, texts=text_data, dictionary=dictionary, coherence='c_v')
        coherence_lda = coherence_model_lda.get_coherence()
        coherence_values.append(coherence_lda)
    multi_coherence_values.append(coherence_values) 
a = np.array(multi_coherence_values)
mea = np.mean(a,axis=0)
std = np.std(a,axis=0)
x = range(start, limit, step)
plt.fill_between(x, mea - std,mea + std, alpha=0.3,   color='y')
plt.plot(x, mea,  color='b')
plt.xlabel("Number of topics")
plt.ylabel("Coherence score")
#plt.legend(("coherence_values"), loc='best')
plt.grid()
#plt.show()
plt.savefig('coherence_score_%s.pdf'%time.time())
plt.show()
sys.exit()
print('\nCoherence Score: ', coherence_lda)
x = range(start, limit, step)
plt.plot(x, coherence_values,color='grey')
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.grid()
#plt.show()
plt.savefig('coherence_score_%s.pdf'%time.time())
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
#pyLDAvis.save_html(lda_display)
# Out:
# [nltk_data] Downloading package wordnet to /home/social-
# [nltk_data]     sim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/social-
# [nltk_data]     sim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Index(['id_h', 'user.time_zone.keyword: Descending',
#        'user.followers_count: Descending', 'extension.polarity: Descending',
#        'hashtags.keyword: Descending', 'extension.subjectivity: Descending',
#        'possibly_sensitive: Descending', 'user.friends_count: Descending',
#        'user.description_m.keyword: Descending', 'Count'],
#       dtype='object')
# id_h
# -0kfmd2vIS8AgNeeR0TvJw    {cybersecurity, cybersecurity, infosec, infose...
# -1VTosFJy_uFKuQdL6UoNA                                     {cisco, infosec}
# -1f25t5ReV9h0YvRLOHlkw    {cybersecurity, hacking, infosec, exploitdev, ...
# -3ThtBx1z_-yTFXq75H9jA                         {LUKS, infosec, root, shell}
# -A7E9AvwmOT_hnI87XaAQg                    {Malware, cybersecurity, infosec}
# Name: hashtags.keyword: Descending, dtype: object
# ['exploit', 'infosec', 'security']
# ['android', 'mobile']
# ['defender', 'microsoft', 'windows', 'exploit']
# ['securityaffairs']
# ['cyberaware', 'cybersecurity', 'infosec']
# ['cybersecurity', 'infosec']
# ['hack', 'infosec', 'intel', 'security']
# ['0daytoday', 'exploit', 'freebsd', 'exploit']
# ['linux']
# ['infosec']
# ['ciberseguridad', 'infosec']
# ['container', 'docker', 'infosec']
# ['exploit', 'windows']
# ['securityaffairs']
# ['securityaffairs']
# ['9milliondownloads', 'infosec', 'netsec']
# ['cybersecurity', 'infosec', 'hack', 'infosec', 'nodejs', 'pent', 'websec', 'infosec', 'vulnerability', 'cybersecurity']
# ['cloudcomputing', 'infosec', 'linux', 'security']
# []
# ['0daytoday', 'exploit', 'exploit']
# ['infosec']
# ['exploit', 'infosec']
# ['exploit', 'infosec']
# ['phishing']
# ['openssh', 'crypto', 'encryption', 'security', 'websecurity', 'itsec']
# (0, '0.205*"exploit" + 0.054*"0daytoday" + 0.054*"windows" + 0.050*"infosec"')
# (1, '0.264*"infosec" + 0.087*"cybersecurity" + 0.067*"securityaffairs" + 0.057*"security"')
# (0, '0.310*"exploit" + 0.077*"windows" + 0.075*"0daytoday" + 0.064*"security"')
# (1, '0.336*"securityaffairs" + 0.030*"exploit" + 0.025*"0daytoday" + 0.021*"infosec"')
# (2, '0.150*"infosec" + 0.076*"container" + 0.076*"docker" + 0.076*"mobile"')
# (3, '0.165*"infosec" + 0.090*"security" + 0.090*"hack" + 0.089*"intel"')
# (4, '0.360*"infosec" + 0.107*"cybersecurity" + 0.072*"linux" + 0.051*"security"')
# (0, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"phishing" + 0.031*"exploit"')
# (1, '0.141*"infosec" + 0.141*"security" + 0.141*"linux" + 0.141*"cloudcomputing"')
# (2, '0.225*"linux" + 0.025*"infosec" + 0.025*"securityaffairs" + 0.025*"phishing"')
# (3, '0.316*"exploit" + 0.094*"0daytoday" + 0.094*"security" + 0.050*"itsec"')
# (4, '0.195*"securityaffairs" + 0.133*"windows" + 0.133*"exploit" + 0.070*"microsoft"')
# (5, '0.407*"infosec" + 0.145*"cybersecurity" + 0.040*"nodejs" + 0.040*"pent"')
# (6, '0.113*"infosec" + 0.112*"security" + 0.112*"hack" + 0.112*"intel"')
# (7, '0.031*"infosec" + 0.031*"phishing" + 0.031*"securityaffairs" + 0.031*"exploit"')
# (0, '0.480*"exploit" + 0.111*"0daytoday" + 0.111*"windows" + 0.058*"freebsd"')
# (1, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"exploit" + 0.031*"phishing"')
# (2, '0.279*"linux" + 0.023*"infosec" + 0.023*"securityaffairs" + 0.023*"exploit"')
# (3, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"exploit" + 0.031*"phishing"')
# (4, '0.422*"infosec" + 0.171*"cybersecurity" + 0.046*"hack" + 0.046*"pent"')
# (5, '0.279*"phishing" + 0.023*"infosec" + 0.023*"securityaffairs" + 0.023*"exploit"')
# (6, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"0daytoday" + 0.031*"phishing"')
# (7, '0.446*"securityaffairs" + 0.158*"cyberaware" + 0.014*"cybersecurity" + 0.014*"infosec"')
# (8, '0.216*"security" + 0.163*"infosec" + 0.058*"encryption" + 0.058*"openssh"')
# (9, '0.211*"infosec" + 0.110*"container" + 0.110*"docker" + 0.110*"android"')
# (10, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"0daytoday" + 0.031*"phishing"')
# (0, '0.358*"infosec" + 0.161*"security" + 0.056*"cloudcomputing" + 0.056*"hack"')
# (1, '0.480*"exploit" + 0.221*"infosec" + 0.102*"0daytoday" + 0.007*"security"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.201*"windows" + 0.201*"exploit" + 0.104*"microsoft" + 0.104*"defender"')
# (4, '0.330*"exploit" + 0.170*"0daytoday" + 0.170*"freebsd" + 0.013*"security"')
# (5, '0.326*"linux" + 0.022*"nodejs" + 0.022*"pent" + 0.022*"netsec"')
# (6, '0.129*"security" + 0.129*"encryption" + 0.129*"openssh" + 0.129*"websecurity"')
# (7, '0.285*"infosec" + 0.215*"cybersecurity" + 0.075*"hack" + 0.075*"pent"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.326*"phishing" + 0.022*"nodejs" + 0.022*"pent" + 0.022*"vulnerability"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.581*"securityaffairs" + 0.014*"infosec" + 0.014*"exploit" + 0.014*"vulnerability"')
# (13, '0.250*"infosec" + 0.129*"cyberaware" + 0.129*"container" + 0.129*"docker"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.177*"security" + 0.139*"infosec" + 0.061*"encryption" + 0.061*"crypto"')
# (3, '0.521*"exploit" + 0.201*"infosec" + 0.152*"0daytoday" + 0.004*"freebsd"')
# (4, '0.154*"security" + 0.154*"intel" + 0.154*"hack" + 0.154*"infosec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.381*"infosec" + 0.193*"cybersecurity" + 0.067*"pent" + 0.067*"hack"')
# (7, '0.217*"cybersecurity" + 0.217*"cyberaware" + 0.217*"infosec" + 0.012*"vulnerability"')
# (8, '0.299*"infosec" + 0.154*"netsec" + 0.154*"9milliondownloads" + 0.154*"ciberseguridad"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.626*"securityaffairs" + 0.012*"pent" + 0.012*"vulnerability" + 0.012*"netsec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.273*"mobile" + 0.273*"android" + 0.015*"pent" + 0.015*"nodejs"')
# (13, '0.367*"linux" + 0.020*"nodejs" + 0.020*"pent" + 0.020*"netsec"')
# (14, '0.261*"windows" + 0.261*"exploit" + 0.134*"defender" + 0.134*"microsoft"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.404*"linux" + 0.019*"nodejs" + 0.019*"pent" + 0.019*"netsec"')
# (1, '0.263*"infosec" + 0.177*"cybersecurity" + 0.091*"pent" + 0.091*"hack"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.545*"infosec" + 0.188*"cybersecurity" + 0.009*"pent" + 0.009*"vulnerability"')
# (4, '0.032*"securityaffairs" + 0.032*"infosec" + 0.031*"pent" + 0.031*"vulnerability"')
# (5, '0.159*"infosec" + 0.159*"cyberaware" + 0.159*"cybersecurity" + 0.159*"mobile"')
# (6, '0.138*"encryption" + 0.138*"openssh" + 0.138*"websecurity" + 0.138*"itsec"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.032*"infosec" + 0.032*"exploit" + 0.032*"securityaffairs" + 0.031*"vulnerability"')
# (9, '0.355*"exploit" + 0.354*"infosec" + 0.122*"security" + 0.006*"0daytoday"')
# (10, '0.404*"phishing" + 0.019*"nodejs" + 0.019*"pent" + 0.019*"vulnerability"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.471*"exploit" + 0.238*"0daytoday" + 0.122*"freebsd" + 0.006*"infosec"')
# (13, '0.663*"securityaffairs" + 0.011*"pent" + 0.011*"vulnerability" + 0.011*"netsec"')
# (14, '0.228*"docker" + 0.228*"infosec" + 0.228*"container" + 0.011*"netsec"')
# (15, '0.270*"windows" + 0.270*"exploit" + 0.138*"defender" + 0.138*"microsoft"')
# (16, '0.187*"linux" + 0.187*"security" + 0.187*"infosec" + 0.187*"cloudcomputing"')
# (17, '0.228*"infosec" + 0.228*"9milliondownloads" + 0.228*"netsec" + 0.011*"exploit"')
# (18, '0.270*"infosec" + 0.138*"intel" + 0.138*"hack" + 0.138*"security"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (20, '0.436*"phishing" + 0.018*"nodejs" + 0.018*"pent" + 0.018*"vulnerability"')
# (4, '0.693*"securityaffairs" + 0.010*"pent" + 0.010*"vulnerability" + 0.010*"netsec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (7, '0.476*"infosec" + 0.163*"docker" + 0.163*"container" + 0.007*"exploit"')
# (12, '0.244*"infosec" + 0.124*"netsec" + 0.124*"linux" + 0.124*"cloudcomputing"')
# (2, '0.307*"android" + 0.307*"mobile" + 0.015*"securityaffairs" + 0.013*"pent"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.302*"infosec" + 0.227*"cybersecurity" + 0.078*"pent" + 0.078*"hack"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.308*"exploit" + 0.308*"windows" + 0.013*"pent" + 0.013*"vulnerability"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.036*"infosec" + 0.036*"cybersecurity" + 0.031*"pent" + 0.031*"vulnerability"')
# (21, '0.363*"exploit" + 0.209*"infosec" + 0.105*"security" + 0.105*"0daytoday"')
# (14, '0.194*"windows" + 0.194*"exploit" + 0.194*"defender" + 0.194*"microsoft"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.308*"infosec" + 0.308*"ciberseguridad" + 0.013*"netsec" + 0.013*"docker"')
# (13, '0.141*"encryption" + 0.141*"openssh" + 0.141*"websecurity" + 0.141*"itsec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.031*"infosec" + 0.031*"cybersecurity" + 0.031*"pent" + 0.031*"hack"')
# (20, '0.482*"exploit" + 0.245*"0daytoday" + 0.009*"pent" + 0.009*"netsec"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (23, '0.282*"infosec" + 0.144*"netsec" + 0.144*"cyberaware" + 0.144*"9milliondownloads"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.460*"exploit" + 0.253*"infosec" + 0.095*"0daytoday" + 0.095*"freebsd"')
# (15, '0.032*"infosec" + 0.031*"9milliondownloads" + 0.031*"nodejs" + 0.031*"vulnerability"')
# (8, '0.305*"infosec" + 0.230*"cybersecurity" + 0.078*"websec" + 0.078*"vulnerability"')
# (14, '0.321*"exploit" + 0.321*"windows" + 0.012*"pent" + 0.012*"vulnerability"')
# (21, '0.272*"linux" + 0.272*"security" + 0.174*"infosec" + 0.138*"cloudcomputing"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.466*"phishing" + 0.017*"nodejs" + 0.017*"pent" + 0.017*"vulnerability"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.199*"windows" + 0.199*"exploit" + 0.199*"defender" + 0.199*"microsoft"')
# (3, '0.321*"infosec" + 0.321*"ciberseguridad" + 0.012*"netsec" + 0.012*"docker"')
# (28, '0.392*"infosec" + 0.364*"exploit" + 0.124*"security" + 0.004*"0daytoday"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.273*"infosec" + 0.183*"cybersecurity" + 0.093*"vulnerability" + 0.093*"websec"')
# (6, '0.203*"intel" + 0.203*"infosec" + 0.203*"hack" + 0.203*"security"')
# (5, '0.286*"windows" + 0.286*"exploit" + 0.146*"microsoft" + 0.146*"defender"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.483*"infosec" + 0.131*"netsec" + 0.131*"9milliondownloads" + 0.131*"ciberseguridad"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.183*"security" + 0.093*"itsec" + 0.093*"crypto" + 0.093*"websecurity"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.498*"exploit" + 0.251*"0daytoday" + 0.128*"freebsd" + 0.004*"pent"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.492*"linux" + 0.016*"nodejs" + 0.016*"pent" + 0.016*"netsec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (27, '0.492*"phishing" + 0.016*"nodejs" + 0.016*"pent" + 0.016*"vulnerability"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (31, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.602*"exploit" + 0.204*"0daytoday" + 0.103*"freebsd" + 0.003*"pent"')
# (10, '0.805*"infosec" + 0.006*"9milliondownloads" + 0.006*"nodejs" + 0.006*"vulnerability"')
# (22, '0.516*"phishing" + 0.016*"nodejs" + 0.016*"pent" + 0.016*"vulnerability"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (27, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (17, '0.347*"infosec" + 0.336*"ciberseguridad" + 0.021*"exploit" + 0.010*"windows"')
# (21, '0.343*"android" + 0.343*"mobile" + 0.011*"exploit" + 0.011*"infosec"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (29, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (30, '0.758*"securityaffairs" + 0.008*"pent" + 0.008*"vulnerability" + 0.008*"netsec"')
# (9, '0.206*"linux" + 0.206*"security" + 0.206*"infosec" + 0.206*"cloudcomputing"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (21, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (33, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.343*"infosec" + 0.343*"cybersecurity" + 0.174*"cyberaware" + 0.005*"vulnerability"')
# (30, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (23, '0.149*"encryption" + 0.149*"openssh" + 0.149*"websecurity" + 0.149*"itsec"')
# (22, '0.413*"exploit" + 0.209*"0daytoday" + 0.209*"freebsd" + 0.006*"pent"')
# (31, '0.273*"infosec" + 0.259*"netsec" + 0.259*"9milliondownloads" + 0.007*"nodejs"')
# (28, '0.518*"exploit" + 0.263*"0daytoday" + 0.007*"pent" + 0.007*"netsec"')
# (27, '0.504*"infosec" + 0.307*"exploit" + 0.104*"security" + 0.003*"pent"')
# (11, '0.353*"android" + 0.353*"mobile" + 0.010*"cybersecurity" + 0.010*"infosec"')
# (29, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.774*"securityaffairs" + 0.007*"pent" + 0.007*"vulnerability" + 0.007*"netsec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.537*"phishing" + 0.015*"nodejs" + 0.015*"pent" + 0.015*"vulnerability"')
# (20, '0.279*"infosec" + 0.187*"cybersecurity" + 0.095*"pent" + 0.095*"hack"')
# (28, '0.037*"infosec" + 0.036*"exploit" + 0.031*"nodejs" + 0.031*"pent"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (37, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.513*"exploit" + 0.258*"0daytoday" + 0.131*"freebsd" + 0.003*"pent"')
# (25, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.588*"infosec" + 0.296*"exploit" + 0.004*"nodejs" + 0.004*"pent"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.361*"exploit" + 0.361*"windows" + 0.009*"pent" + 0.009*"vulnerability"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (31, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (29, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (7, '0.788*"securityaffairs" + 0.007*"pent" + 0.007*"vulnerability" + 0.007*"netsec"')
# (36, '0.267*"exploit" + 0.267*"security" + 0.267*"infosec" + 0.007*"pent"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.212*"intel" + 0.212*"infosec" + 0.212*"hack" + 0.212*"security"')
# (8, '0.361*"infosec" + 0.361*"cybersecurity" + 0.009*"pent" + 0.009*"vulnerability"')
# (0, '0.108*"infosec" + 0.067*"security" + 0.061*"linux" + 0.059*"windows"')
# (1, '0.202*"infosec" + 0.159*"exploit" + 0.078*"cybersecurity" + 0.060*"securityaffairs"')
# (0, '0.190*"exploit" + 0.153*"infosec" + 0.117*"security" + 0.044*"itsec"')
# (1, '0.126*"infosec" + 0.069*"windows" + 0.069*"defender" + 0.069*"microsoft"')
# (2, '0.258*"securityaffairs" + 0.178*"exploit" + 0.097*"0daytoday" + 0.016*"phishing"')
# (3, '0.300*"infosec" + 0.153*"cybersecurity" + 0.044*"hack" + 0.044*"nodejs"')
# (4, '0.164*"linux" + 0.090*"security" + 0.090*"cloudcomputing" + 0.090*"windows"')
# (0, '0.233*"infosec" + 0.097*"cybersecurity" + 0.097*"security" + 0.097*"hack"')
# (1, '0.225*"linux" + 0.025*"exploit" + 0.025*"windows" + 0.025*"infosec"')
# (2, '0.396*"infosec" + 0.174*"exploit" + 0.118*"cybersecurity" + 0.063*"cyberaware"')
# (3, '0.161*"infosec" + 0.161*"container" + 0.161*"docker" + 0.018*"exploit"')
# (4, '0.161*"infosec" + 0.161*"netsec" + 0.161*"9milliondownloads" + 0.018*"exploit"')
# (5, '0.094*"security" + 0.094*"openssh" + 0.094*"itsec" + 0.094*"encryption"')
# (6, '0.347*"securityaffairs" + 0.125*"ciberseguridad" + 0.125*"infosec" + 0.014*"phishing"')
# (7, '0.340*"exploit" + 0.118*"0daytoday" + 0.118*"windows" + 0.063*"freebsd"')
# (0, '0.194*"infosec" + 0.194*"securityaffairs" + 0.131*"cybersecurity" + 0.069*"hack"')
# (1, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"0daytoday" + 0.031*"phishing"')
# (2, '0.279*"phishing" + 0.023*"infosec" + 0.023*"securityaffairs" + 0.023*"exploit"')
# (3, '0.279*"linux" + 0.023*"securityaffairs" + 0.023*"infosec" + 0.023*"exploit"')
# (4, '0.222*"mobile" + 0.222*"android" + 0.019*"infosec" + 0.019*"securityaffairs"')
# (5, '0.131*"exploit" + 0.069*"0daytoday" + 0.069*"security" + 0.069*"encryption"')
# (6, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"0daytoday" + 0.031*"ciberseguridad"')
# (7, '0.235*"exploit" + 0.235*"windows" + 0.122*"microsoft" + 0.122*"defender"')
# (8, '0.270*"infosec" + 0.269*"exploit" + 0.110*"security" + 0.058*"cloudcomputing"')
# (9, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"exploit" + 0.031*"0daytoday"')
# (10, '0.359*"infosec" + 0.124*"cybersecurity" + 0.065*"intel" + 0.065*"cyberaware"')
# (0, '0.294*"infosec" + 0.235*"cybersecurity" + 0.062*"vulnerability" + 0.062*"hack"')
# (1, '0.115*"itsec" + 0.115*"security" + 0.115*"crypto" + 0.115*"openssh"')
# (2, '0.450*"infosec" + 0.232*"exploit" + 0.082*"netsec" + 0.082*"9milliondownloads"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.203*"infosec" + 0.203*"docker" + 0.203*"container" + 0.014*"netsec"')
# (5, '0.438*"exploit" + 0.223*"0daytoday" + 0.115*"freebsd" + 0.008*"securityaffairs"')
# (6, '0.227*"security" + 0.167*"infosec" + 0.079*"linux" + 0.079*"intel"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.250*"windows" + 0.250*"exploit" + 0.129*"defender" + 0.129*"microsoft"')
# (11, '0.250*"infosec" + 0.250*"ciberseguridad" + 0.017*"netsec" + 0.017*"docker"')
# (12, '0.581*"securityaffairs" + 0.014*"pent" + 0.014*"vulnerability" + 0.014*"netsec"')
# (13, '0.326*"phishing" + 0.022*"nodejs" + 0.022*"pent" + 0.022*"vulnerability"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.160*"exploit" + 0.160*"windows" + 0.160*"infosec" + 0.082*"microsoft"')
# (2, '0.626*"securityaffairs" + 0.012*"pent" + 0.012*"vulnerability" + 0.012*"netsec"')
# (3, '0.292*"infosec" + 0.220*"cybersecurity" + 0.076*"pent" + 0.076*"hack"')
# (4, '0.342*"exploit" + 0.173*"0daytoday" + 0.089*"infosec" + 0.089*"freebsd"')
# (5, '0.367*"linux" + 0.021*"securityaffairs" + 0.020*"vulnerability" + 0.020*"nodejs"')
# (6, '0.367*"phishing" + 0.020*"nodejs" + 0.020*"pent" + 0.020*"vulnerability"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.154*"cyberaware" + 0.154*"cybersecurity" + 0.154*"infosec" + 0.154*"android"')
# (10, '0.180*"intel" + 0.180*"hack" + 0.180*"security" + 0.180*"infosec"')
# (11, '0.515*"infosec" + 0.261*"exploit" + 0.007*"nodejs" + 0.007*"pent"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.180*"infosec" + 0.180*"linux" + 0.180*"cloudcomputing" + 0.180*"security"')
# (15, '0.217*"exploit" + 0.217*"security" + 0.217*"infosec" + 0.012*"pent"')
# (16, '0.134*"encryption" + 0.134*"openssh" + 0.134*"websecurity" + 0.134*"itsec"')
# (0, '0.292*"exploit" + 0.292*"windows" + 0.014*"pent" + 0.014*"vulnerability"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.404*"phishing" + 0.019*"nodejs" + 0.019*"pent" + 0.019*"vulnerability"')
# (3, '0.663*"securityaffairs" + 0.011*"pent" + 0.011*"vulnerability" + 0.011*"netsec"')
# (4, '0.228*"cybersecurity" + 0.228*"cyberaware" + 0.228*"infosec" + 0.011*"vulnerability"')
# (5, '0.476*"infosec" + 0.193*"exploit" + 0.099*"netsec" + 0.099*"9milliondownloads"')
# (6, '0.187*"intel" + 0.187*"infosec" + 0.187*"hack" + 0.187*"security"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.471*"exploit" + 0.238*"0daytoday" + 0.122*"freebsd" + 0.006*"pent"')
# (9, '0.228*"exploit" + 0.228*"security" + 0.228*"infosec" + 0.011*"pent"')
# (10, '0.404*"linux" + 0.019*"nodejs" + 0.019*"pent" + 0.019*"netsec"')
# (11, '0.324*"infosec" + 0.196*"cybersecurity" + 0.067*"vulnerability" + 0.067*"hack"')
# (12, '0.138*"encryption" + 0.138*"openssh" + 0.138*"websecurity" + 0.138*"itsec"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.292*"mobile" + 0.292*"android" + 0.014*"pent" + 0.014*"nodejs"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.187*"linux" + 0.187*"security" + 0.187*"cloudcomputing" + 0.187*"infosec"')
# (17, '0.122*"infosec" + 0.122*"exploit" + 0.122*"microsoft" + 0.122*"container"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.542*"infosec" + 0.280*"exploit" + 0.006*"nodejs" + 0.006*"pent"')
# (16, '0.285*"infosec" + 0.273*"cybersecurity" + 0.140*"cyberaware" + 0.140*"phishing"')
# (9, '0.179*"infosec" + 0.092*"windows" + 0.092*"defender" + 0.092*"microsoft"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.308*"mobile" + 0.308*"android" + 0.013*"pent" + 0.013*"nodejs"')
# (4, '0.141*"encryption" + 0.141*"openssh" + 0.141*"websecurity" + 0.141*"itsec"')
# (6, '0.485*"exploit" + 0.197*"0daytoday" + 0.100*"freebsd" + 0.100*"windows"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (20, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.308*"infosec" + 0.308*"ciberseguridad" + 0.013*"netsec" + 0.013*"docker"')
# (1, '0.693*"securityaffairs" + 0.010*"pent" + 0.010*"vulnerability" + 0.010*"netsec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.194*"infosec" + 0.194*"linux" + 0.194*"security" + 0.194*"cloudcomputing"')
# (7, '0.436*"linux" + 0.018*"infosec" + 0.018*"nodejs" + 0.018*"pent"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.144*"encryption" + 0.144*"openssh" + 0.144*"websecurity" + 0.144*"itsec"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.648*"exploit" + 0.167*"0daytoday" + 0.006*"infosec" + 0.006*"pent"')
# (5, '0.390*"exploit" + 0.199*"0daytoday" + 0.199*"freebsd" + 0.007*"pent"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.321*"exploit" + 0.321*"windows" + 0.012*"pent" + 0.012*"vulnerability"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.321*"mobile" + 0.321*"android" + 0.012*"pent" + 0.012*"nodejs"')
# (12, '0.245*"cybersecurity" + 0.245*"cyberaware" + 0.245*"infosec" + 0.009*"vulnerability"')
# (15, '0.221*"infosec" + 0.221*"security" + 0.221*"linux" + 0.112*"cloudcomputing"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.248*"infosec" + 0.126*"security" + 0.126*"hack" + 0.126*"intel"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (17, '0.718*"securityaffairs" + 0.009*"pent" + 0.009*"vulnerability" + 0.009*"netsec"')
# (23, '0.697*"infosec" + 0.144*"cybersecurity" + 0.006*"exploit" + 0.005*"pent"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.199*"windows" + 0.199*"exploit" + 0.199*"defender" + 0.199*"microsoft"')
# (6, '0.292*"infosec" + 0.118*"cybersecurity" + 0.060*"hack" + 0.060*"vulnerability"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.252*"exploit" + 0.252*"security" + 0.252*"infosec" + 0.008*"pent"')
# (20, '0.252*"docker" + 0.252*"infosec" + 0.252*"container" + 0.008*"netsec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.492*"linux" + 0.016*"nodejs" + 0.016*"pent" + 0.016*"netsec"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (21, '0.593*"exploit" + 0.203*"0daytoday" + 0.103*"freebsd" + 0.003*"pent"')
# (14, '0.114*"infosec" + 0.114*"exploit" + 0.114*"microsoft" + 0.114*"defender"')
# (11, '0.252*"infosec" + 0.129*"cybersecurity" + 0.127*"security" + 0.127*"linux"')
# (22, '0.146*"encryption" + 0.146*"openssh" + 0.146*"websecurity" + 0.146*"itsec"')
# (27, '0.308*"infosec" + 0.231*"cybersecurity" + 0.079*"pent" + 0.079*"hack"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.252*"netsec" + 0.252*"9milliondownloads" + 0.252*"infosec" + 0.008*"nodejs"')
# (28, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.333*"infosec" + 0.333*"ciberseguridad" + 0.011*"netsec" + 0.011*"docker"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.032*"infosec" + 0.031*"9milliondownloads" + 0.031*"nodejs" + 0.031*"vulnerability"')
# (29, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.147*"encryption" + 0.147*"openssh" + 0.147*"websecurity" + 0.147*"itsec"')
# (17, '0.339*"infosec" + 0.172*"9milliondownloads" + 0.172*"netsec" + 0.172*"ciberseguridad"')
# (6, '0.032*"securityaffairs" + 0.032*"cybersecurity" + 0.032*"infosec" + 0.031*"vulnerability"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (31, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (28, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.344*"mobile" + 0.344*"android" + 0.010*"pent" + 0.010*"nodejs"')
# (27, '0.503*"infosec" + 0.303*"exploit" + 0.103*"security" + 0.003*"phishing"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.314*"infosec" + 0.252*"cybersecurity" + 0.064*"vulnerability" + 0.064*"hack"')
# (21, '0.115*"infosec" + 0.115*"exploit" + 0.115*"microsoft" + 0.115*"defender"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (32, '0.537*"linux" + 0.015*"nodejs" + 0.015*"pent" + 0.015*"netsec"')
# (25, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.537*"phishing" + 0.015*"nodejs" + 0.015*"pent" + 0.015*"vulnerability"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (33, '0.774*"securityaffairs" + 0.007*"pent" + 0.007*"vulnerability" + 0.007*"netsec"')
# (30, '0.209*"intel" + 0.209*"infosec" + 0.209*"hack" + 0.209*"security"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.583*"infosec" + 0.293*"exploit" + 0.004*"windows" + 0.004*"nodejs"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (23, '0.518*"exploit" + 0.263*"0daytoday" + 0.007*"pent" + 0.007*"netsec"')
# (28, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.149*"encryption" + 0.149*"openssh" + 0.149*"websecurity" + 0.149*"itsec"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.383*"exploit" + 0.130*"infosec" + 0.130*"0daytoday" + 0.130*"freebsd"')
# (4, '0.277*"infosec" + 0.186*"cybersecurity" + 0.094*"pent" + 0.094*"hack"')
# (11, '0.353*"infosec" + 0.353*"cybersecurity" + 0.010*"pent" + 0.010*"vulnerability"')
# (21, '0.689*"exploit" + 0.176*"0daytoday" + 0.005*"pent" + 0.005*"netsec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.212*"infosec" + 0.212*"security" + 0.212*"intel" + 0.212*"hack"')
# (17, '0.831*"infosec" + 0.005*"9milliondownloads" + 0.005*"nodejs" + 0.005*"vulnerability"')
# (12, '0.291*"infosec" + 0.146*"cybersecurity" + 0.074*"vulnerability" + 0.074*"hack"')
# (2, '0.418*"windows" + 0.418*"exploit" + 0.005*"pent" + 0.005*"vulnerability"')
# (14, '0.347*"linux" + 0.176*"security" + 0.176*"infosec" + 0.176*"cloudcomputing"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (35, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.361*"mobile" + 0.361*"android" + 0.009*"pent" + 0.009*"nodejs"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (30, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.361*"infosec" + 0.361*"cybersecurity" + 0.009*"pent" + 0.009*"vulnerability"')
# (36, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.267*"exploit" + 0.267*"security" + 0.267*"infosec" + 0.007*"pent"')
# (29, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.234*"infosec" + 0.145*"exploit" + 0.069*"cybersecurity" + 0.038*"0daytoday"')
# (1, '0.107*"securityaffairs" + 0.086*"security" + 0.076*"linux" + 0.046*"itsec"')
# (0, '0.340*"infosec" + 0.160*"cybersecurity" + 0.046*"hack" + 0.046*"websec"')
# (1, '0.208*"securityaffairs" + 0.143*"windows" + 0.142*"exploit" + 0.078*"microsoft"')
# (2, '0.198*"infosec" + 0.149*"security" + 0.103*"linux" + 0.056*"cloudcomputing"')
# (3, '0.333*"exploit" + 0.112*"infosec" + 0.102*"0daytoday" + 0.055*"freebsd"')
# (4, '0.090*"security" + 0.089*"websecurity" + 0.089*"itsec" + 0.089*"openssh"')
# (0, '0.342*"infosec" + 0.129*"cybersecurity" + 0.067*"hack" + 0.067*"security"')
# (1, '0.387*"securityaffairs" + 0.139*"cyberaware" + 0.022*"cybersecurity" + 0.019*"infosec"')
# (2, '0.366*"exploit" + 0.212*"infosec" + 0.100*"windows" + 0.011*"security"')
# (3, '0.080*"security" + 0.080*"windows" + 0.080*"itsec" + 0.080*"crypto"')
# (4, '0.236*"linux" + 0.125*"security" + 0.125*"infosec" + 0.125*"cloudcomputing"')
# (5, '0.187*"android" + 0.187*"mobile" + 0.021*"exploit" + 0.021*"0daytoday"')
# (6, '0.375*"exploit" + 0.193*"0daytoday" + 0.102*"freebsd" + 0.011*"securityaffairs"')
# (7, '0.161*"infosec" + 0.161*"netsec" + 0.161*"9milliondownloads" + 0.018*"exploit"')
# (0, '0.031*"infosec" + 0.031*"securityaffairs" + 0.031*"phishing" + 0.031*"linux"')
# (1, '0.279*"phishing" + 0.023*"infosec" + 0.023*"securityaffairs" + 0.023*"exploit"')
# (2, '0.122*"security" + 0.122*"encryption" + 0.122*"openssh" + 0.122*"crypto"')
# (3, '0.310*"infosec" + 0.135*"cybersecurity" + 0.091*"hack" + 0.048*"pent"')
# (4, '0.235*"infosec" + 0.122*"netsec" + 0.122*"docker" + 0.122*"9milliondownloads"')
# (5, '0.185*"infosec" + 0.185*"cybersecurity" + 0.185*"cyberaware" + 0.015*"securityaffairs"')
# (6, '0.419*"exploit" + 0.183*"infosec" + 0.124*"0daytoday" + 0.065*"freebsd"')
# (7, '0.031*"infosec" + 0.031*"phishing" + 0.031*"cybersecurity" + 0.031*"windows"')
# (8, '0.222*"infosec" + 0.222*"ciberseguridad" + 0.019*"securityaffairs" + 0.019*"exploit"')
# (9, '0.150*"windows" + 0.150*"exploit" + 0.150*"linux" + 0.078*"infosec"')
# (10, '0.523*"securityaffairs" + 0.015*"infosec" + 0.015*"linux" + 0.015*"exploit"')
# (0, '0.359*"infosec" + 0.095*"security" + 0.095*"hack" + 0.095*"intel"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.326*"linux" + 0.022*"nodejs" + 0.022*"pent" + 0.022*"netsec"')
# (3, '0.342*"exploit" + 0.163*"infosec" + 0.078*"0daytoday" + 0.078*"windows"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.203*"infosec" + 0.203*"netsec" + 0.203*"9milliondownloads" + 0.014*"nodejs"')
# (7, '0.302*"infosec" + 0.253*"cybersecurity" + 0.067*"vulnerability" + 0.067*"hack"')
# (8, '0.129*"security" + 0.129*"cloudcomputing" + 0.129*"linux" + 0.129*"infosec"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.129*"security" + 0.129*"encryption" + 0.129*"openssh" + 0.129*"websecurity"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.581*"securityaffairs" + 0.014*"infosec" + 0.014*"exploit" + 0.014*"vulnerability"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.367*"linux" + 0.020*"infosec" + 0.020*"cyberaware" + 0.020*"cybersecurity"')
# (1, '0.217*"security" + 0.217*"exploit" + 0.217*"infosec" + 0.012*"pent"')
# (2, '0.465*"infosec" + 0.189*"exploit" + 0.097*"9milliondownloads" + 0.097*"netsec"')
# (3, '0.350*"exploit" + 0.180*"0daytoday" + 0.180*"freebsd" + 0.010*"pent"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.367*"phishing" + 0.020*"nodejs" + 0.020*"pent" + 0.020*"vulnerability"')
# (6, '0.134*"encryption" + 0.134*"openssh" + 0.134*"websecurity" + 0.134*"itsec"')
# (7, '0.626*"securityaffairs" + 0.012*"cybersecurity" + 0.012*"infosec" + 0.012*"vulnerability"')
# (8, '0.261*"windows" + 0.261*"exploit" + 0.134*"defender" + 0.134*"microsoft"')
# (9, '0.134*"infosec" + 0.134*"linux" + 0.134*"security" + 0.134*"cloudcomputing"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.232*"infosec" + 0.119*"security" + 0.119*"hack" + 0.119*"intel"')
# (12, '0.422*"exploit" + 0.217*"0daytoday" + 0.012*"pent" + 0.012*"netsec"')
# (13, '0.273*"ciberseguridad" + 0.273*"infosec" + 0.015*"netsec" + 0.015*"docker"')
# (14, '0.300*"infosec" + 0.240*"cybersecurity" + 0.063*"vulnerability" + 0.063*"hack"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.238*"infosec" + 0.122*"cloudcomputing" + 0.122*"security" + 0.122*"linux"')
# (1, '0.228*"cybersecurity" + 0.228*"cyberaware" + 0.228*"infosec" + 0.011*"vulnerability"')
# (2, '0.460*"infosec" + 0.155*"cybersecurity" + 0.053*"pent" + 0.053*"hack"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.568*"exploit" + 0.194*"0daytoday" + 0.100*"freebsd" + 0.005*"pent"')
# (5, '0.544*"securityaffairs" + 0.188*"linux" + 0.009*"infosec" + 0.009*"vulnerability"')
# (6, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (7, '0.033*"infosec" + 0.031*"9milliondownloads" + 0.031*"nodejs" + 0.031*"vulnerability"')
# (8, '0.187*"intel" + 0.187*"infosec" + 0.187*"hack" + 0.187*"security"')
# (9, '0.292*"mobile" + 0.292*"android" + 0.014*"pent" + 0.014*"nodejs"')
# (10, '0.032*"exploit" + 0.032*"infosec" + 0.031*"nodejs" + 0.031*"pent"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.403*"phishing" + 0.020*"cybersecurity" + 0.020*"infosec" + 0.019*"pent"')
# (14, '0.270*"windows" + 0.270*"exploit" + 0.138*"defender" + 0.138*"microsoft"')
# (15, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (16, '0.270*"infosec" + 0.138*"exploit" + 0.138*"docker" + 0.138*"container"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.138*"itsec" + 0.138*"security" + 0.138*"crypto" + 0.138*"openssh"')
# (9, '0.238*"exploit" + 0.238*"security" + 0.238*"infosec" + 0.010*"pent"')
# (21, '0.320*"exploit" + 0.163*"0daytoday" + 0.163*"mobile" + 0.163*"android"')
# (17, '0.244*"infosec" + 0.124*"intel" + 0.124*"security" + 0.124*"hack"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.436*"phishing" + 0.018*"nodejs" + 0.018*"pent" + 0.018*"vulnerability"')
# (14, '0.379*"exploit" + 0.379*"infosec" + 0.008*"nodejs" + 0.008*"pent"')
# (22, '0.302*"infosec" + 0.227*"cybersecurity" + 0.078*"hack" + 0.078*"vulnerability"')
# (7, '0.032*"securityaffairs" + 0.032*"infosec" + 0.031*"pent" + 0.031*"vulnerability"')
# (19, '0.246*"exploit" + 0.165*"linux" + 0.084*"freebsd" + 0.084*"0daytoday"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (20, '0.693*"securityaffairs" + 0.010*"pent" + 0.010*"vulnerability" + 0.010*"netsec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.277*"infosec" + 0.141*"netsec" + 0.141*"docker" + 0.141*"9milliondownloads"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.564*"infosec" + 0.193*"ciberseguridad" + 0.009*"cybersecurity" + 0.008*"pent"')
# (3, '0.466*"linux" + 0.017*"nodejs" + 0.017*"pent" + 0.017*"netsec"')
# (1, '0.112*"infosec" + 0.112*"cloudcomputing" + 0.112*"microsoft" + 0.112*"linux"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.321*"exploit" + 0.321*"windows" + 0.012*"pent" + 0.012*"vulnerability"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.248*"security" + 0.126*"encryption" + 0.126*"openssh" + 0.126*"crypto"')
# (5, '0.248*"infosec" + 0.126*"hack" + 0.126*"netsec" + 0.126*"intel"')
# (2, '0.718*"securityaffairs" + 0.009*"pent" + 0.009*"vulnerability" + 0.009*"netsec"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.310*"infosec" + 0.249*"cybersecurity" + 0.064*"vulnerability" + 0.064*"hack"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.538*"infosec" + 0.271*"exploit" + 0.092*"ciberseguridad" + 0.003*"cybersecurity"')
# (6, '0.491*"exploit" + 0.248*"0daytoday" + 0.126*"freebsd" + 0.005*"pent"')
# (16, '0.466*"phishing" + 0.017*"nodejs" + 0.017*"pent" + 0.017*"vulnerability"')
# (11, '0.321*"android" + 0.321*"mobile" + 0.012*"securityaffairs" + 0.012*"pent"')
# (15, '0.251*"infosec" + 0.128*"intel" + 0.128*"security" + 0.128*"hack"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (27, '0.333*"infosec" + 0.333*"ciberseguridad" + 0.011*"netsec" + 0.011*"docker"')
# (1, '0.498*"infosec" + 0.300*"exploit" + 0.102*"security" + 0.003*"pent"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.333*"exploit" + 0.333*"windows" + 0.011*"pent" + 0.011*"vulnerability"')
# (26, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (14, '0.739*"securityaffairs" + 0.008*"pent" + 0.008*"vulnerability" + 0.008*"netsec"')
# (20, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (7, '0.146*"itsec" + 0.146*"openssh" + 0.146*"crypto" + 0.146*"websecurity"')
# (6, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (21, '0.333*"mobile" + 0.333*"android" + 0.011*"pent" + 0.011*"nodejs"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (28, '0.252*"docker" + 0.252*"infosec" + 0.252*"container" + 0.008*"netsec"')
# (18, '0.457*"exploit" + 0.276*"infosec" + 0.094*"security" + 0.094*"0daytoday"')
# (30, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.677*"linux" + 0.010*"nodejs" + 0.010*"pent" + 0.010*"netsec"')
# (6, '0.310*"infosec" + 0.233*"cybersecurity" + 0.079*"pent" + 0.079*"hack"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.290*"exploit" + 0.290*"windows" + 0.147*"defender" + 0.147*"microsoft"')
# (23, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (22, '0.516*"phishing" + 0.016*"nodejs" + 0.016*"pent" + 0.016*"vulnerability"')
# (12, '0.258*"docker" + 0.258*"infosec" + 0.258*"container" + 0.008*"netsec"')
# (3, '0.206*"intel" + 0.206*"infosec" + 0.206*"hack" + 0.206*"security"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (20, '0.344*"android" + 0.344*"mobile" + 0.011*"cloudcomputing" + 0.010*"linux"')
# (7, '0.677*"infosec" + 0.010*"9milliondownloads" + 0.010*"nodejs" + 0.010*"vulnerability"')
# (27, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (29, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (30, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (34, '0.503*"infosec" + 0.256*"exploit" + 0.087*"docker" + 0.087*"container"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (25, '0.509*"exploit" + 0.256*"0daytoday" + 0.130*"freebsd" + 0.004*"pent"')
# (9, '0.293*"exploit" + 0.293*"windows" + 0.149*"android" + 0.149*"mobile"')
# (33, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.774*"securityaffairs" + 0.007*"pent" + 0.007*"vulnerability" + 0.007*"netsec"')
# (4, '0.277*"infosec" + 0.186*"cybersecurity" + 0.094*"pent" + 0.094*"websec"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (21, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (20, '0.033*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (5, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.537*"linux" + 0.015*"nodejs" + 0.015*"pent" + 0.015*"netsec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (26, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (28, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (36, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.033*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (21, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (27, '0.347*"linux" + 0.176*"security" + 0.176*"infosec" + 0.176*"cloudcomputing"')
# (20, '0.361*"android" + 0.361*"mobile" + 0.009*"cybersecurity" + 0.009*"infosec"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (17, '0.036*"exploit" + 0.036*"infosec" + 0.031*"nodejs" + 0.031*"pent"')
# (33, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (6, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (37, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (34, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (32, '0.280*"exploit" + 0.253*"infosec" + 0.253*"security" + 0.034*"windows"')
# (25, '0.416*"exploit" + 0.416*"infosec" + 0.006*"nodejs" + 0.006*"pent"')
# (0, '0.107*"securityaffairs" + 0.076*"linux" + 0.076*"security" + 0.047*"openssh"')
# (1, '0.233*"infosec" + 0.143*"exploit" + 0.068*"cybersecurity" + 0.039*"security"')
# (0, '0.174*"infosec" + 0.174*"securityaffairs" + 0.065*"intel" + 0.065*"docker"')
# (1, '0.314*"infosec" + 0.188*"cybersecurity" + 0.054*"hack" + 0.054*"websec"')
# (2, '0.242*"exploit" + 0.127*"0daytoday" + 0.069*"freebsd" + 0.069*"netsec"')
# (3, '0.189*"exploit" + 0.161*"infosec" + 0.080*"windows" + 0.080*"security"')
# (4, '0.097*"security" + 0.097*"crypto" + 0.097*"itsec" + 0.097*"websecurity"')
# (0, '0.438*"infosec" + 0.080*"netsec" + 0.080*"9milliondownloads" + 0.080*"ciberseguridad"')
# (1, '0.139*"exploit" + 0.129*"windows" + 0.078*"security" + 0.068*"encryption"')
# (2, '0.503*"exploit" + 0.153*"0daytoday" + 0.081*"linux" + 0.009*"freebsd"')
# (3, '0.031*"infosec" + 0.031*"freebsd" + 0.031*"linux" + 0.031*"exploit"')
# (4, '0.446*"securityaffairs" + 0.018*"infosec" + 0.018*"exploit" + 0.018*"freebsd"')
# (5, '0.236*"infosec" + 0.236*"cybersecurity" + 0.125*"cyberaware" + 0.014*"exploit"')
# (6, '0.187*"android" + 0.187*"mobile" + 0.021*"infosec" + 0.021*"freebsd"')
# (7, '0.252*"infosec" + 0.107*"security" + 0.077*"hack" + 0.077*"cybersecurity"')
# (0, '0.031*"infosec" + 0.031*"phishing" + 0.031*"0daytoday" + 0.031*"securityaffairs"')
# (1, '0.031*"infosec" + 0.031*"exploit" + 0.031*"phishing" + 0.031*"securityaffairs"')
# (2, '0.501*"exploit" + 0.165*"infosec" + 0.148*"0daytoday" + 0.006*"freebsd"')
# (3, '0.235*"windows" + 0.235*"exploit" + 0.122*"defender" + 0.122*"microsoft"')
# (4, '0.289*"infosec" + 0.131*"securityaffairs" + 0.088*"cybersecurity" + 0.088*"hack"')
# (5, '0.222*"android" + 0.222*"mobile" + 0.019*"infosec" + 0.019*"exploit"')
# (6, '0.122*"security" + 0.122*"encryption" + 0.122*"openssh" + 0.122*"crypto"')
# (7, '0.235*"infosec" + 0.122*"netsec" + 0.122*"9milliondownloads" + 0.122*"ciberseguridad"')
# (8, '0.279*"phishing" + 0.023*"infosec" + 0.023*"securityaffairs" + 0.023*"exploit"')
# (9, '0.185*"infosec" + 0.185*"container" + 0.185*"docker" + 0.015*"securityaffairs"')
# (10, '0.239*"infosec" + 0.162*"linux" + 0.162*"cybersecurity" + 0.085*"security"')
# (0, '0.291*"infosec" + 0.126*"security" + 0.085*"cybersecurity" + 0.085*"hack"')
# (1, '0.495*"infosec" + 0.145*"cybersecurity" + 0.075*"cyberaware" + 0.075*"netsec"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.371*"securityaffairs" + 0.129*"infosec" + 0.129*"docker" + 0.129*"container"')
# (5, '0.250*"mobile" + 0.250*"android" + 0.017*"pent" + 0.017*"nodejs"')
# (6, '0.031*"infosec" + 0.031*"9milliondownloads" + 0.031*"nodejs" + 0.031*"vulnerability"')
# (7, '0.129*"security" + 0.129*"encryption" + 0.129*"openssh" + 0.129*"websecurity"')
# (8, '0.326*"phishing" + 0.022*"cybersecurity" + 0.022*"infosec" + 0.022*"pent"')
# (9, '0.250*"exploit" + 0.250*"windows" + 0.017*"pent" + 0.017*"vulnerability"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.532*"exploit" + 0.156*"0daytoday" + 0.081*"freebsd" + 0.081*"linux"')
# (12, '0.170*"exploit" + 0.170*"defender" + 0.170*"microsoft" + 0.170*"windows"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.520*"infosec" + 0.180*"ciberseguridad" + 0.010*"netsec" + 0.010*"docker"')
# (4, '0.315*"infosec" + 0.238*"exploit" + 0.160*"security" + 0.082*"hack"')
# (5, '0.217*"docker" + 0.217*"infosec" + 0.217*"container" + 0.012*"netsec"')
# (6, '0.208*"exploit" + 0.208*"windows" + 0.107*"microsoft" + 0.107*"defender"')
# (7, '0.180*"infosec" + 0.180*"linux" + 0.180*"cloudcomputing" + 0.180*"security"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.367*"linux" + 0.020*"nodejs" + 0.020*"pent" + 0.020*"netsec"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (12, '0.434*"exploit" + 0.220*"0daytoday" + 0.113*"cyberaware" + 0.033*"cybersecurity"')
# (13, '0.286*"infosec" + 0.187*"cybersecurity" + 0.052*"hack" + 0.052*"vulnerability"')
# (14, '0.134*"encryption" + 0.134*"openssh" + 0.134*"websecurity" + 0.134*"itsec"')
# (15, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.626*"securityaffairs" + 0.012*"pent" + 0.012*"vulnerability" + 0.012*"netsec"')
# (0, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.663*"securityaffairs" + 0.011*"pent" + 0.011*"vulnerability" + 0.011*"netsec"')
# (2, '0.187*"windows" + 0.187*"exploit" + 0.187*"defender" + 0.187*"microsoft"')
# (3, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (5, '0.159*"infosec" + 0.159*"cyberaware" + 0.159*"cybersecurity" + 0.159*"mobile"')
# (6, '0.445*"exploit" + 0.279*"infosec" + 0.116*"windows" + 0.006*"nodejs"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (8, '0.196*"infosec" + 0.131*"exploit" + 0.131*"cybersecurity" + 0.067*"pent"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (10, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (11, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (12, '0.138*"encryption" + 0.138*"openssh" + 0.138*"websecurity" + 0.138*"itsec"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (14, '0.238*"exploit" + 0.122*"intel" + 0.122*"hack" + 0.122*"infosec"')
# (15, '0.545*"infosec" + 0.188*"cybersecurity" + 0.009*"pent" + 0.009*"vulnerability"')
# (16, '0.404*"linux" + 0.019*"nodejs" + 0.019*"pent" + 0.019*"netsec"')
# (17, '0.404*"phishing" + 0.019*"nodejs" + 0.019*"pent" + 0.019*"vulnerability"')
# (18, '0.292*"infosec" + 0.292*"ciberseguridad" + 0.014*"securityaffairs" + 0.014*"netsec"')
# (19, '0.272*"infosec" + 0.156*"security" + 0.080*"cloudcomputing" + 0.080*"linux"')
# (6, '0.194*"infosec" + 0.194*"intel" + 0.194*"hack" + 0.194*"security"')
# (10, '0.603*"infosec" + 0.013*"9milliondownloads" + 0.013*"nodejs" + 0.013*"vulnerability"')
# (17, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.436*"phishing" + 0.018*"nodejs" + 0.018*"pent" + 0.018*"vulnerability"')
# (11, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (13, '0.033*"infosec" + 0.032*"exploit" + 0.031*"nodejs" + 0.031*"pent"')
# (2, '0.362*"exploit" + 0.200*"infosec" + 0.063*"windows" + 0.063*"microsoft"')
# (16, '0.244*"infosec" + 0.124*"linux" + 0.124*"cloudcomputing" + 0.124*"security"')
# (7, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (21, '0.308*"infosec" + 0.308*"ciberseguridad" + 0.013*"netsec" + 0.013*"docker"')
# (8, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (18, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (20, '0.308*"mobile" + 0.308*"android" + 0.013*"pent" + 0.013*"nodejs"')
# (14, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (15, '0.194*"infosec" + 0.194*"9milliondownloads" + 0.194*"netsec" + 0.194*"linux"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (1, '0.308*"exploit" + 0.308*"windows" + 0.013*"pent" + 0.013*"vulnerability"')
# (5, '0.315*"infosec" + 0.268*"cybersecurity" + 0.069*"vulnerability" + 0.069*"hack"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (3, '0.718*"securityaffairs" + 0.009*"pent" + 0.009*"vulnerability" + 0.009*"netsec"')
# (14, '0.322*"infosec" + 0.321*"ciberseguridad" + 0.012*"exploit" + 0.012*"netsec"')
# (13, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (7, '0.381*"exploit" + 0.154*"0daytoday" + 0.078*"microsoft" + 0.078*"freebsd"')
# (8, '0.144*"encryption" + 0.144*"openssh" + 0.144*"websecurity" + 0.144*"itsec"')
# (11, '0.321*"linux" + 0.321*"phishing" + 0.012*"pent" + 0.012*"vulnerability"')
# (20, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (23, '0.199*"linux" + 0.199*"security" + 0.199*"infosec" + 0.199*"cloudcomputing"')
# (24, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (22, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (4, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (16, '0.032*"securityaffairs" + 0.031*"pent" + 0.031*"vulnerability" + 0.031*"netsec"')
# (18, '0.245*"netsec" + 0.245*"9milliondownloads" + 0.245*"infosec" + 0.009*"nodejs"')
# (10, '0.331*"infosec" + 0.265*"cybersecurity" + 0.068*"pent" + 0.068*"hack"')
# (6, '0.558*"infosec" + 0.282*"exploit" + 0.005*"nodejs" + 0.005*"pent"')
# (25, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (2, '0.321*"mobile" + 0.321*"android" + 0.012*"pent" + 0.012*"nodejs"')
# (19, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (21, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
# (9, '0.031*"nodejs" + 0.031*"netsec" + 0.031*"pent" + 0.031*"websec"')
